# %%
import numpy as np
from sklearn.decomposition import PCA

# Generate a random dataset
np.random.seed(1)
X = np.random.rand(100, 4)

# Create a PCA instance
pca = PCA(n_components=2)

# Fit the data to the model
pca.fit(X)

# Transform the data to the first two principal components
X_pca = pca.transform(X)

# Print the original data shape and the transformed data shape
print("Original shape:", X.shape)
print("Transformed shape:", X_pca.shape)
X_pca
# Out:
# Original shape: (100, 4)
# Transformed shape: (100, 2)
# array([[ 0.16700075, -0.32718336],
#        [ 0.63695648, -0.02678028],
#        [ 0.04699687, -0.10319727],
#        [ 0.1330302 , -0.49141242],
#        [ 0.23417183, -0.12330308],
#        [-0.44760183, -0.32473652],
#        [-0.22485503, -0.20881323],
#        [ 0.19374011, -0.31301041],
#        [-0.35588592,  0.25658312],
#        [-0.20416624, -0.56504099],
#        [-0.47166722, -0.36393254],
#        [ 0.23513654,  0.53975193],
#        [ 0.49153804, -0.34285425],
#        [ 0.45990567,  0.32543243],
#        [ 0.07704115,  0.10836457],
#        [ 0.29883389,  0.30851966],
#        [ 0.25452499,  0.2131053 ],
#        [-0.40554264,  0.50882089],
#        [ 0.21444653,  0.07909177],
#        [-0.34991238,  0.16141552],
#        [-0.38122772,  0.27764969],
#        [-0.13194512, -0.29346657],
#        [-0.14994175, -0.52528703],
#        [ 0.09881861,  0.0808326 ],
#        [-0.17653598, -0.47648917],
#        [ 0.02328114,  0.45550056],
#        [-0.28777416, -0.6207634 ],
#        [-0.2028307 , -0.18719735],
#        [-0.32117403, -0.51589317],
#        [-0.3878468 ,  0.29143768],
#        [ 0.84277765, -0.09125258],
#        [-0.36846875, -0.09840705],
#        [ 0.26154238, -0.01221633],
#        [ 0.19827925,  0.53374394],
#        [-0.32969546,  0.24891365],
#        [ 0.41632837, -0.07426808],
#        [ 0.59952351, -0.15749745],
#        [ 0.27464286, -0.42658298],
#        [ 0.15443468, -0.21230548],
#        [-0.05996448,  0.30033031],
#        [ 0.08116599,  0.02492572],
#        [ 0.67671182, -0.17554593],
#        [-0.15830018, -0.35365545],
#        [-0.05512807,  0.0023055 ],
#        [ 0.20144541, -0.22099902],
#        [ 0.0987463 ,  0.52146566],
#        [ 0.08462751, -0.32328203],
#        [-0.05721212, -0.04712164],
#        [-0.5523283 ,  0.12213098],
#        [ 0.35987554,  0.04261584],
#        [-0.51872014,  0.29314206],
#        [ 0.05073983,  0.12996196],
#        [-0.60309937, -0.37901345],
#        [ 0.57736189, -0.15407776],
#        [ 0.10972645,  0.49405087],
#        [ 0.38899568, -0.3434131 ],
#        [-0.24211438, -0.13797392],
#        [-0.45889808, -0.12175727],
#        [-0.1031637 ,  0.02111027],
#        [ 0.2551719 , -0.12855777],
#        [-0.02547906,  0.19151996],
#        [-0.08514464, -0.34128339],
#        [-0.29429228, -0.70281033],
#        [-0.27942064, -0.10554931],
#        [-0.06083226, -0.2062888 ],
#        [-0.50239017,  0.07894617],
#        [-0.19696459,  0.23037691],
#        [ 0.22379563,  0.08074058],
#        [-0.24166787,  0.38068192],
#        [ 0.25036592, -0.17907715],
#        [-0.4860303 ,  0.17654092],
#        [-0.09130167, -0.1227602 ],
#        [-0.24216649, -0.11452822],
#        [ 0.1396307 ,  0.11807042],
#        [ 0.24549918,  0.71447674],
#        [-0.50213688,  0.07248813],
#        [ 0.39248366,  0.08047107],
#        [-0.19105711,  0.25319452],
#        [ 0.5080627 , -0.10501987],
#        [ 0.0121596 , -0.27967389],
#        [ 0.19414496, -0.01194784],
#        [ 0.10258922, -0.29788728],
#        [-0.04488987, -0.4061551 ],
#        [ 0.21780471,  0.53387161],
#        [-0.19772557,  0.2601808 ],
#        [-0.69904723,  0.03837137],
#        [ 0.11855858,  0.17361688],
#        [-0.09153648,  0.25517078],
#        [ 0.31157709,  0.30931011],
#        [-0.38579353,  0.05556202],
#        [ 0.2067701 ,  0.47105202],
#        [-0.58467288,  0.38442907],
#        [ 0.36003009,  0.22525017],
#        [ 0.31086364, -0.3158377 ],
#        [-0.34550565,  0.2865483 ],
#        [-0.08820963,  0.59362125],
#        [ 0.25001614,  0.35851503],
#        [ 0.35089794, -0.29868573],
#        [ 0.30561773,  0.09419046],
#        [-0.05612209, -0.00360653]])
